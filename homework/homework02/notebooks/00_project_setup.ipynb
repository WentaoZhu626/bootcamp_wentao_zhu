# %% [markdown]
# # Environment & Config Check

# %%
import os

import numpy as np
from dotenv import load_dotenv

load_dotenv(dotenv_path=".env")

print("API_KEY exists:", bool(os.getenv("API_KEY")))

values = np.array([1, 2, 3, 4])
print("Original array:", values)
print("Array multiplied by 2:", values * 2)
# Out:
# API_KEY exists: True
# Original array: [1 2 3 4]
# Array multiplied by 2: [2 4 6 8]

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "src"))

from config import get_key, load_env

load_env()
print("Config helper found API_KEY:", bool(get_key("API_KEY")))
# Out:
# Config helper found API_KEY: True
